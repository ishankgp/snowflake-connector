# %%
import snowflake.connector as snow
import pandas as pd

# set up connection parameters
user = 'SDLC_USER'
password = ''
account = ''
database = 'HS_DEEPLEARNING'
schema = 'ADHOC'
table = 'ALL_METRICS_DASH_419V1'

# establish a connection to Snowflake
conn = snow.connect(user=user, password=password, account=account, database=database, schema=schema)

# execute a query to load data from the specified table
query = f"SELECT * FROM {table}"
df = pd.read_sql(query, conn)

# display the resulting Pandas DataFrame
display(df.head())
# Out:
#              DISTRICT        PLANNING_AREA  ACCTG_YR  ACCTG_MTH  ACCTG_WK  \
# 0           7088 Mesa  7088_A  Albuquerque      2022          2         6
# 1  7744 New York City       7744_Q  Queens      2022          3        13
# 2        8107 Houston   8107_A  Alexandria      2022          9        38
# 3        8555 Chicago      8555_S  Up West      2022          8        33
# 4    4766 Ohio Valley  4766_S  Parkersburg      2022          3        10
#
#    PHONE_SNS  CREATES  B2B_CREATES  D2C_CREATES  CREATES_EXPECTED_COMPLETED  \
# 0       27.0    214.0        114.0         47.0                       173.0
# 1       25.0    211.0         52.0         48.0                       174.0
# 2        8.0     65.0         39.0         10.0                        51.0
# 3        6.0     67.0         18.0         21.0                        56.0
# 4        1.0     28.0         10.0          6.0                        20.0
#
# ...

# %%
#pip uninstall snowflake-connector-python

# %%
#pip install snowflake-connector-python
